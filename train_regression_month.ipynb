# %%
import pandas as pd
import matplotlib.pyplot as plt
import catboost
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn import metrics
from sklearn.model_selection import KFold
import pickle

pd.options.display.max_columns = 100

# %%
train_month_df = pd.read_excel('data/train.xlsx', sheet_name='Monthly').drop(0)
train_quart_df = pd.read_excel('data/train.xlsx', sheet_name='Quarterly').drop(0)

# %%
train_month_df['month'] = [int(x[-2:]) for x in train_month_df['Unnamed: 0'].tolist()]
train_month_df['year'] = [int(x[:4]) for x in train_month_df['Unnamed: 0'].tolist()]

train_quart_df['month'] = [int(x[-2:]) for x in train_quart_df['Unnamed: 0'].tolist()]
train_quart_df['year'] = [int(x[:4]) for x in train_quart_df['Unnamed: 0'].tolist()]

train_month_df['year'] -= train_month_df['year'].min()
train_quart_df['year'] -= train_quart_df['year'].min()

train_month_df['month_num'] = train_month_df['month'] + train_month_df['year'] * 12
train_quart_df['month_num'] = train_quart_df['month'] + train_quart_df['year'] * 12

train_month_df.drop('Unnamed: 0', axis=1, inplace=True)
train_quart_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
from utils import classes

# %%
for cl in classes:
    for x in cl:
        train_month_df[x] = (train_month_df[x].values - np.mean(train_month_df[x])) / np.std(train_month_df[x])

# %%
from utils import make_features_month_reg

def get_features(values):
    values = np.array(values)
    
    features, target = [], []

    for i in range(37, len(values)):
        features.append(make_features_month_reg(values[:i]))
        target.append(values[i]-values[i-1])

    return features, target

# %%
models = []

for id in range(len(classes)):

    all_features, all_target = [], []
    
    for col in classes[id]:
        a = train_month_df[col].dropna().tolist()


        features, target = get_features(a)
        all_features.append(features)
        all_target.append(target)
    
    all_features = np.concatenate(all_features, axis=0)
    all_target = np.concatenate(all_target, axis=0)
    
    
    cur_models = []
    for x in range(5):
        model = catboost.CatBoostRegressor(
            random_seed=x,
            learning_rate=0.03
        )
        model.fit(all_features, all_target, verbose=100)

        cur_models.append(model)

    models.append(cur_models)

with open('models_month_reg.pkl', 'wb') as f:
    pickle.dump(models, f)
# Out:
# 0:	learn: 0.5164131	total: 63.5ms	remaining: 1m 3s
# 100:	learn: 0.3136487	total: 344ms	remaining: 3.06s
# 200:	learn: 0.2762444	total: 688ms	remaining: 2.74s
# 300:	learn: 0.2491797	total: 1s	remaining: 2.33s
# 400:	learn: 0.2272320	total: 1.27s	remaining: 1.9s
# 500:	learn: 0.2075945	total: 1.61s	remaining: 1.6s
# 600:	learn: 0.1913329	total: 1.89s	remaining: 1.25s
# 700:	learn: 0.1742203	total: 2.17s	remaining: 927ms
# 800:	learn: 0.1584464	total: 2.46s	remaining: 612ms
# 900:	learn: 0.1447856	total: 2.8s	remaining: 307ms
# 999:	learn: 0.1329301	total: 3.17s	remaining: 0us
# 0:	learn: 0.5162454	total: 6.56ms	remaining: 6.55s
# 100:	learn: 0.3137189	total: 409ms	remaining: 3.64s
# 200:	learn: 0.2770139	total: 819ms	remaining: 3.25s
# 300:	learn: 0.2495301	total: 1.26s	remaining: 2.93s
# 400:	learn: 0.2264388	total: 1.68s	remaining: 2.51s
# 500:	learn: 0.2079383	total: 2.12s	remaining: 2.11s
# 600:	learn: 0.1890310	total: 2.54s	remaining: 1.68s
# 700:	learn: 0.1718090	total: 2.92s	remaining: 1.24s
# 800:	learn: 0.1572078	total: 3.35s	remaining: 833ms
# 900:	learn: 0.1448491	total: 3.74s	remaining: 411ms
# 100:	learn: 0.5411780	total: 293ms	remaining: 2.61s
# 200:	learn: 0.3941124	total: 599ms	remaining: 2.38s
# 300:	learn: 0.2989826	total: 883ms	remaining: 2.05s
# 400:	learn: 0.2368249	total: 1.16s	remaining: 1.73s
# 500:	learn: 0.1803320	total: 1.42s	remaining: 1.42s
# 600:	learn: 0.1459567	total: 1.7s	remaining: 1.13s
# 700:	learn: 0.1167290	total: 1.97s	remaining: 842ms
# 800:	learn: 0.0964130	total: 2.25s	remaining: 559ms
# 900:	learn: 0.0768022	total: 2.55s	remaining: 280ms
# 999:	learn: 0.0612302	total: 2.83s	remaining: 0us
# 0:	learn: 1.2472479	total: 6.26ms	remaining: 6.25s
# 100:	learn: 0.5446109	total: 289ms	remaining: 2.57s
# 200:	learn: 0.3907017	total: 554ms	remaining: 2.2s
# 300:	learn: 0.2948175	total: 819ms	remaining: 1.9s
# 400:	learn: 0.2348847	total: 1.11s	remaining: 1.65s
# 500:	learn: 0.1892787	total: 1.38s	remaining: 1.37s
# 600:	learn: 0.1504340	total: 1.64s	remaining: 1.09s
# 700:	learn: 0.1221452	total: 1.93s	remaining: 821ms
# 800:	learn: 0.0989546	total: 2.19s	remaining: 544ms
# 900:	learn: 0.0808513	total: 2.45s	remaining: 269ms
# 999:	learn: 0.0671451	total: 2.77s	remaining: 0us
# 0:	learn: 1.2466423	total: 3.15ms	remaining: 3.15s
# 100:	learn: 0.5453433	total: 256ms	remaining: 2.28s
# 200:	learn: 0.3904696	total: 513ms	remaining: 2.04s
# 300:	learn: 0.2977419	total: 780ms	remaining: 1.81s
# 400:	learn: 0.2393568	total: 1.04s	remaining: 1.56s
# 500:	learn: 0.1890506	total: 1.31s	remaining: 1.3s
# 600:	learn: 0.1543230	total: 1.56s	remaining: 1.04s
# 700:	learn: 0.1240110	total: 1.82s	remaining: 776ms
# 800:	learn: 0.1007792	total: 2.08s	remaining: 516ms
# 900:	learn: 0.0833793	total: 2.34s	remaining: 257ms
# 999:	learn: 0.0700971	total: 2.59s	remaining: 0us
# 0:	learn: 1.2449373	total: 4.38ms	remaining: 4.37s
# 100:	learn: 0.5435276	total: 252ms	remaining: 2.24s
# 200:	learn: 0.3861798	total: 528ms	remaining: 2.1s
# 300:	learn: 0.2959409	total: 785ms	remaining: 1.82s
# 400:	learn: 0.2400970	total: 1.09s	remaining: 1.63s
# 500:	learn: 0.1874012	total: 1.33s	remaining: 1.33s
# 600:	learn: 0.1498843	total: 1.59s	remaining: 1.05s
# 700:	learn: 0.1191904	total: 1.84s	remaining: 786ms
# 800:	learn: 0.0966847	total: 2.06s	remaining: 511ms
# 900:	learn: 0.0792514	total: 2.26s	remaining: 248ms
# 999:	learn: 0.0624873	total: 2.47s	remaining: 0us
# 0:	learn: 0.2324041	total: 4.5ms	remaining: 4.5s
# 100:	learn: 0.1475271	total: 273ms	remaining: 2.43s
# 200:	learn: 0.1278688	total: 518ms	remaining: 2.06s
# 300:	learn: 0.1147480	total: 776ms	remaining: 1.8s
# 400:	learn: 0.1033802	total: 1.03s	remaining: 1.54s
# 500:	learn: 0.0928508	total: 1.3s	remaining: 1.29s
# 600:	learn: 0.0841923	total: 1.57s	remaining: 1.04s
# 700:	learn: 0.0766192	total: 1.83s	remaining: 779ms
# 800:	learn: 0.0698839	total: 2.07s	remaining: 515ms
# 900:	learn: 0.0643930	total: 2.32s	remaining: 255ms
# 999:	learn: 0.0593783	total: 2.57s	remaining: 0us
# 0:	learn: 0.2318743	total: 2.97ms	remaining: 2.97s
# 100:	learn: 0.1469169	total: 254ms	remaining: 2.26s
# 200:	learn: 0.1275600	total: 508ms	remaining: 2.02s
# 300:	learn: 0.1148804	total: 768ms	remaining: 1.78s
# 400:	learn: 0.1029873	total: 1.05s	remaining: 1.56s
# 500:	learn: 0.0929202	total: 1.3s	remaining: 1.29s
# 600:	learn: 0.0844038	total: 1.55s	remaining: 1.03s
# 700:	learn: 0.0769203	total: 1.8s	remaining: 768ms
# 800:	learn: 0.0699687	total: 2.05s	remaining: 510ms
# 900:	learn: 0.0641213	total: 2.31s	remaining: 254ms
# 999:	learn: 0.0586174	total: 2.56s	remaining: 0us
# 0:	learn: 0.2321413	total: 2.58ms	remaining: 2.58s
# 100:	learn: 0.1474315	total: 260ms	remaining: 2.31s
# 200:	learn: 0.1284043	total: 536ms	remaining: 2.13s
# 300:	learn: 0.1156600	total: 788ms	remaining: 1.83s
# 400:	learn: 0.1039705	total: 1.03s	remaining: 1.54s
# 500:	learn: 0.0931197	total: 1.29s	remaining: 1.28s
# 600:	learn: 0.0847988	total: 1.53s	remaining: 1.01s
# 700:	learn: 0.0773891	total: 1.78s	remaining: 761ms
# 800:	learn: 0.0701389	total: 2.04s	remaining: 507ms
# 900:	learn: 0.0639451	total: 2.3s	remaining: 253ms
# 999:	learn: 0.0584863	total: 2.54s	remaining: 0us
# 0:	learn: 0.2321883	total: 2.64ms	remaining: 2.63s
# 100:	learn: 0.1486693	total: 284ms	remaining: 2.53s
# 200:	learn: 0.1293720	total: 532ms	remaining: 2.11s
# 300:	learn: 0.1157928	total: 780ms	remaining: 1.81s
# 400:	learn: 0.1036001	total: 1.03s	remaining: 1.54s
# 500:	learn: 0.0931519	total: 1.3s	remaining: 1.29s
# 600:	learn: 0.0835498	total: 1.56s	remaining: 1.03s
# 700:	learn: 0.0753573	total: 1.82s	remaining: 777ms
# 800:	learn: 0.0688584	total: 2.08s	remaining: 518ms
# 900:	learn: 0.0628225	total: 2.34s	remaining: 257ms
# 999:	learn: 0.0574991	total: 2.69s	remaining: 0us
# 0:	learn: 0.2320810	total: 2.36ms	remaining: 2.36s
# 100:	learn: 0.1464022	total: 262ms	remaining: 2.33s
# 200:	learn: 0.1274923	total: 513ms	remaining: 2.04s
# 300:	learn: 0.1148717	total: 767ms	remaining: 1.78s
# 400:	learn: 0.1035155	total: 1.04s	remaining: 1.55s
# 500:	learn: 0.0936521	total: 1.3s	remaining: 1.29s
# 600:	learn: 0.0845661	total: 1.56s	remaining: 1.03s
# 700:	learn: 0.0770696	total: 1.8s	remaining: 770ms
# 800:	learn: 0.0700151	total: 2.07s	remaining: 513ms
# 900:	learn: 0.0642463	total: 2.32s	remaining: 255ms
# 999:	learn: 0.0589810	total: 2.58s	remaining: 0us
# 0:	learn: 0.0794500	total: 2.95ms	remaining: 2.95s
# 100:	learn: 0.0388816	total: 272ms	remaining: 2.42s
# 200:	learn: 0.0334165	total: 554ms	remaining: 2.2s
# 300:	learn: 0.0301996	total: 823ms	remaining: 1.91s
# 400:	learn: 0.0272525	total: 1.1s	remaining: 1.64s
# 500:	learn: 0.0246655	total: 1.37s	remaining: 1.37s
# 600:	learn: 0.0223990	total: 1.66s	remaining: 1.1s
# 700:	learn: 0.0204191	total: 1.95s	remaining: 833ms
# 800:	learn: 0.0187409	total: 2.25s	remaining: 560ms
# 900:	learn: 0.0172562	total: 2.52s	remaining: 277ms
# 999:	learn: 0.0159701	total: 2.79s	remaining: 0us
# 0:	learn: 0.0790070	total: 4.28ms	remaining: 4.28s
# 100:	learn: 0.0391755	total: 287ms	remaining: 2.55s
# 200:	learn: 0.0336447	total: 575ms	remaining: 2.28s
# 300:	learn: 0.0302678	total: 858ms	remaining: 1.99s
# 400:	learn: 0.0273460	total: 1.16s	remaining: 1.74s
# 500:	learn: 0.0246620	total: 1.45s	remaining: 1.44s
# 600:	learn: 0.0224664	total: 1.72s	remaining: 1.14s
# 700:	learn: 0.0205682	total: 1.99s	remaining: 849ms
# 800:	learn: 0.0190777	total: 2.27s	remaining: 564ms
# 900:	learn: 0.0175909	total: 2.56s	remaining: 281ms
# 999:	learn: 0.0161933	total: 2.83s	remaining: 0us
# 0:	learn: 0.0791550	total: 3.12ms	remaining: 3.12s
# 100:	learn: 0.0390730	total: 259ms	remaining: 2.31s
# 200:	learn: 0.0335179	total: 527ms	remaining: 2.1s
# 300:	learn: 0.0300821	total: 790ms	remaining: 1.83s
# 400:	learn: 0.0271285	total: 1.06s	remaining: 1.59s
# 500:	learn: 0.0243652	total: 1.34s	remaining: 1.34s
# 600:	learn: 0.0220893	total: 1.61s	remaining: 1.07s
# 700:	learn: 0.0202379	total: 1.89s	remaining: 805ms
# 800:	learn: 0.0186149	total: 2.18s	remaining: 543ms
# 900:	learn: 0.0171553	total: 2.49s	remaining: 273ms
# 999:	learn: 0.0159059	total: 2.8s	remaining: 0us
# 0:	learn: 0.0791752	total: 3.52ms	remaining: 3.52s
# 100:	learn: 0.0390256	total: 330ms	remaining: 2.94s
# 200:	learn: 0.0335139	total: 644ms	remaining: 2.56s
# 300:	learn: 0.0302620	total: 935ms	remaining: 2.17s
# 400:	learn: 0.0273059	total: 1.21s	remaining: 1.8s
# 500:	learn: 0.0247405	total: 1.5s	remaining: 1.49s
# 600:	learn: 0.0224881	total: 1.77s	remaining: 1.17s
# 700:	learn: 0.0205836	total: 2.03s	remaining: 867ms
# 800:	learn: 0.0190077	total: 2.29s	remaining: 570ms
# 900:	learn: 0.0175933	total: 2.57s	remaining: 282ms
# 999:	learn: 0.0163604	total: 2.83s	remaining: 0us
# 0:	learn: 0.0792065	total: 2.89ms	remaining: 2.89s
# 100:	learn: 0.0390450	total: 277ms	remaining: 2.47s
# 200:	learn: 0.0336308	total: 546ms	remaining: 2.17s
# 300:	learn: 0.0304367	total: 821ms	remaining: 1.91s
# 400:	learn: 0.0276159	total: 1.09s	remaining: 1.62s
# 500:	learn: 0.0249796	total: 1.35s	remaining: 1.34s
# 600:	learn: 0.0227332	total: 1.67s	remaining: 1.11s
# 700:	learn: 0.0206104	total: 1.94s	remaining: 827ms
# 800:	learn: 0.0188339	total: 2.21s	remaining: 549ms
# 900:	learn: 0.0173883	total: 2.5s	remaining: 274ms
# 999:	learn: 0.0160468	total: 2.8s	remaining: 0us
